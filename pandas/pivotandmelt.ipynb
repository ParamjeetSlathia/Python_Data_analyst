# %%
# MELT()

import pandas as pd  

var = pd.DataFrame({"days":[1,2,3,4,5,6],"eng":[10,12,14,15,16,12],"maths":[12,18,19,13,14,16]})

var
# Out:
#    days  eng  maths
# 0     1   10     12
# 1     2   12     18
# 2     3   14     19
# 3     4   15     13
# 4     5   16     14
# 5     6   12     16

# %%
pd.melt(var)
